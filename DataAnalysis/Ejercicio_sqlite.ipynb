# %%
import pandas as pd
import sqlite3
import os
os.getcwd()
# Out:
# 'c:\\Users\\emita\\Bootcamp\\REPO PROFE\\COPIA REPO\\repo-clase-dsvlcsep24\\5-Bases_de_datos\\SQL\\Ejercicios'

# %%
connection = sqlite3.connect("chinook.db")

crsr = connection.cursor()

# %%
def sql_query(query):

    crsr.execute(query)

    ans = crsr.fetchall()

    names = [description[0] for description in crsr.description]

    return pd.DataFrame(ans,columns=names)

# %% [markdown]
# PRIMERA PARTE
# 1. Muestra los clientes de brasil*

# %%
query = """

SELECT * from customers
WHERE customers.Country = 'Brazil'

"""
brazil_clients = sql_query(query)
brazil_clients
# Out:
#    CustomerId  FirstName   LastName  \
# 0           1       Luís  Gonçalves
# 1          10    Eduardo    Martins
# 2          11  Alexandre      Rocha
# 3          12    Roberto    Almeida
# 4          13   Fernanda      Ramos
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                  Woodstock Discos
# 2                              Banco do Brasil S.A.
# 3                                            Riotur
# 4                                              None
#
#                            Address                 City State Country  \
# 0  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP  Brazil
# 1        Rua Dr. Falcão Filho, 155            São Paulo    SP  Brazil
# 2               Av. Paulista, 2022            São Paulo    SP  Brazil
# 3                 Praça Pio X, 119       Rio de Janeiro    RJ  Brazil
# 4                     Qe 7 Bloco G             Brasília    DF  Brazil
#
# ...

# %% [markdown]
# 2. Muestrame los empleados que son agentes de ventas*

# %%
empleados_agentes_ventas = """

SELECT *  
FROM employees
WHERE employees.Title = 'Sales Support Agent'

"""
sql_query(empleados_agentes_ventas)
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  \
# 0           3  Peacock      Jane  Sales Support Agent          2
# 1           4     Park  Margaret  Sales Support Agent          2
# 2           5  Johnson     Steve  Sales Support Agent          2
#
#              BirthDate             HireDate           Address     City State  \
# 0  1973-08-29 00:00:00  2002-04-01 00:00:00     1111 6 Ave SW  Calgary    AB
# 1  1947-09-19 00:00:00  2003-05-03 00:00:00  683 10 Street SW  Calgary    AB
# 2  1965-03-03 00:00:00  2003-10-17 00:00:00      7727B 41 Ave  Calgary    AB
#
#   Country PostalCode              Phone                Fax  \
# 0  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 1  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 2  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
#
#                       Email
# 0      jane@chinookcorp.com
# 1  margaret@chinookcorp.com
# 2     steve@chinookcorp.com

# %% [markdown]
# 3. Muestrame las canciones de ‘AC/DC’

# %%
ACDC_Songs = """

SELECT tracks.Name, artists.Name
FROM tracks
INNER JOIN albums
ON tracks.AlbumId = albums.AlbumId

INNER JOIN artists 
ON albums.ArtistId = artists.ArtistId

WHERE artists.Name = "AC/DC"


"""
sql_query(ACDC_Songs)
# Out:
#                                        Name   Name
# 0   For Those About To Rock (We Salute You)  AC/DC
# 1                     Put The Finger On You  AC/DC
# 2                           Let's Get It Up  AC/DC
# 3                          Inject The Venom  AC/DC
# 4                                Snowballed  AC/DC
# 5                                Evil Walks  AC/DC
# 6                                    C.O.D.  AC/DC
# 7                        Breaking The Rules  AC/DC
# 8                  Night Of The Long Knives  AC/DC
# 9                                Spellbound  AC/DC
# 10                                  Go Down  AC/DC
# 11                              Dog Eat Dog  AC/DC
# 12                        Let There Be Rock  AC/DC
# 13                           Bad Boy Boogie  AC/DC
# 14                            Problem Child  AC/DC
# 15                                 Overdose  AC/DC
# 16             Hell Ain't A Bad Place To Be  AC/DC
# ...

# %% [markdown]
# 4. Muestra los clientes que no sean de USA: Nombre completo, ID, Pais*

# %%
not_USA = """ 

SELECT customers.FirstName, customers.LastName, customers.CustomerId, customers.Country
FROM customers
WHERE customers.Country <> 'USA'
"""
sql_query(not_USA)
# Out:
#     FirstName      LastName  CustomerId         Country
# 0        Luís     Gonçalves           1          Brazil
# 1      Leonie        Köhler           2         Germany
# 2    François      Tremblay           3          Canada
# 3       Bjørn        Hansen           4          Norway
# 4   František   Wichterlová           5  Czech Republic
# 5      Helena          Holý           6  Czech Republic
# 6      Astrid        Gruber           7         Austria
# 7        Daan       Peeters           8         Belgium
# 8        Kara       Nielsen           9         Denmark
# 9     Eduardo       Martins          10          Brazil
# 10  Alexandre         Rocha          11          Brazil
# 11    Roberto       Almeida          12          Brazil
# 12   Fernanda         Ramos          13          Brazil
# 13       Mark       Philips          14          Canada
# 14   Jennifer      Peterson          15          Canada
# 15     Robert         Brown          29          Canada
# ...

# %% [markdown]
# 5. Muestrame los empleados que son agentes de ventas: Nombre completo, Dirección (Ciudad, Estado, Pais) y email

# %%
agentes_de_ventas = """ 

SELECT employees.LastName, employees.FirstName, employees.Address, employees.City, employees.State, employees.Country, employees.Email
FROM employees 
WHERE employees.Title = 'Sales Support Agent'
"""
sql_query(agentes_de_ventas)
# Out:
#   LastName FirstName           Address     City State Country  \
# 0  Peacock      Jane     1111 6 Ave SW  Calgary    AB  Canada
# 1     Park  Margaret  683 10 Street SW  Calgary    AB  Canada
# 2  Johnson     Steve      7727B 41 Ave  Calgary    AB  Canada
#
#                       Email
# 0      jane@chinookcorp.com
# 1  margaret@chinookcorp.com
# 2     steve@chinookcorp.com

# %% [markdown]
# 6. Muestra una lista con los paises que aparecen a los que se ha facturado, la lista no
# debe contener paises repetidos*

# %%
paises_facturados = """ 

SELECT DISTINCT customers.Country
FROM customers 
INNER JOIN invoices ON customers.CustomerId = invoices.CustomerId

"""
sql_query(paises_facturados)
# Out:
#            Country
# 0           Brazil
# 1          Germany
# 2           Canada
# 3           Norway
# 4   Czech Republic
# 5          Austria
# 6          Belgium
# 7          Denmark
# 8              USA
# 9         Portugal
# 10          France
# 11         Finland
# 12         Hungary
# 13         Ireland
# 14           Italy
# 15     Netherlands
# 16          Poland
# 17           Spain
# 18          Sweden
# 19  United Kingdom
# 20       Australia
# 21       Argentina
# 22           Chile
# 23           India

# %% [markdown]
# 7. Muestra una lista con los estados de USA de donde son los clientes, la lista no debe contener estados repetidos

# %%
clientes_USA =  """ 

SELECT DISTINCT customers.State
FROM customers
WHERE customers.Country = 'USA'

"""
sql_query(clientes_USA)
# Out:
#    State
# 0     CA
# 1     WA
# 2     NY
# 3     NV
# 4     FL
# 5     MA
# 6     IL
# 7     WI
# 8     TX
# 9     AZ
# 10    UT

# %% [markdown]
# 8. Cuantos articulos tiene la factura 37*

# %%
invoice_37 =  """ 

SELECT InvoiceId, sum (Quantity) AS Total_Quantity

FROM invoice_items 
WHERE invoice_items.InvoiceId = 37
GROUP BY InvoiceId
"""
sql_query(invoice_37)
# Out:
#    InvoiceId  Total_Quantity
# 0         37               4

# %% [markdown]
# 9. Cuantas canciones tiene ‘AC/DC’

# %%
Canciones_ACDC =  """ 

SELECT artists.Name, COUNT(*) as ACDC_Totals
FROM tracks
INNER JOIN albums 
ON albums.AlbumId = tracks.AlbumId

INNER JOIN artists 
ON albums.ArtistId = artists.ArtistId

WHERE artists.Name = "AC/DC"

GROUP BY artists.Name

"""
sql_query(Canciones_ACDC)
# Out:
#     Name  ACDC_Totals
# 0  AC/DC           18

# %% [markdown]
# 10. Cuantos articulos tiene cada factura*

# %%
articulos_por_invoice =  """ 

SELECT InvoiceId, COUNT (Quantity) as Total_arts
FROM invoice_items
GROUP BY invoice_items.InvoiceId

"""
sql_query(articulos_por_invoice)
# Out:
#      InvoiceId  Total_arts
# 0            1           2
# 1            2           4
# 2            3           6
# 3            4           9
# 4            5          14
# ..         ...         ...
# 407        408           4
# 408        409           6
# 409        410           9
# 410        411          14
# 411        412           1
#
# [412 rows x 2 columns]

# %% [markdown]
# 11. Muestrame cuantos facturas hay de cada pais

# %%
facturas_por_pais = """ 

SELECT invoices.InvoiceId, customers.Country, SUM(invoices.InvoiceId) AS Invoices_per_country
FROM customers
INNER JOIN invoices 
ON invoices.CustomerId = customers.CustomerId  

GROUP BY customers.Country
"""
sql_query(facturas_por_pais)
# Out:
#     InvoiceId         Country  Invoices_per_country
# 0         119       Argentina                  1729
# 1          21       Australia                  1043
# 2          78         Austria                  1568
# 3           3         Belgium                  1428
# 4          98          Brazil                  7399
# 5          99          Canada                 11963
# 6          22           Chile                  1176
# 7          77  Czech Republic                  3143
# 8          56         Denmark                  1288
# 9          53         Finland                  1757
# 10        105          France                  7168
# 11          1         Germany                  4697
# 12         85         Hungary                  1617
# 13        120           India                  2758
# 14         10         Ireland                  1477
# 15         63           Italy                  1337
# 16         32     Netherlands                  1610
# ...

# %% [markdown]
# 12. Cuantas facturas ha habido en 2009 y 2011*

# %%
invoices_09_11 = """ 

SELECT COUNT(*) AS Total_facturas_09_11
FROM invoices 
WHERE InvoiceDate LIKE '2009%' 
    OR InvoiceDate LIKE '2010%' 
    OR InvoiceDate LIKE '2011%'

"""
sql_query(invoices_09_11)
# Out:
#    Total_facturas_09_11
# 0                   249

# %% [markdown]
# 14. Cuantos clientes hay de españa y de Brazil

# %%
clientes_esp_bra = """ 

SELECT COUNT(*) AS Total_clientes_Esp_Bra
FROM customers
WHERE Country = 'Brazil' 
    OR Country = 'Spain'
"""
sql_query(clientes_esp_bra)
# Out:
#    Total_clientes_Esp_Bra
# 0                       6

# %% [markdown]
# 15. Muestrame las canciones que su titulo empieza por ‘You’

# %%
songs_you = """ 

SELECT * 
FROM tracks
WHERE Name LIKE 'you%' 

"""
sql_query(songs_you)
# Out:
#     TrackId                                           Name  AlbumId  \
# 0        39                                You Oughta Know        6
# 1        44                                      You Learn        6
# 2        50                    You Oughta Know (Alternate)        6
# 3        99                             Your Time Has Come       11
# 4       337                                   You Shook Me       30
# 5       349                                You Shook Me(2)       30
# 6       549                                You Fool No One       43
# 7       623            You Fool No One (Alternate Version)       50
# 8       753                             You Keep On Moving       58
# 9       812  You Can't Do it Right (With the One You Love)       65
# 10     1155                                   You're Crazy       90
# 11     1163                            You Ain't the First       91
# 12     1185                              You Could Be Mine       92
# ...

# %% [markdown]
# SEGUNDA PARTE
# 1. Facturas de Clientes de Brasil, Nombre del cliente, Id de factura, fecha de la factura
# y el pais de la factura*

# %%
invoices_bra = """ 

SELECT customers.FirstName, customers.LastName, invoices.InvoiceId, invoices.InvoiceDate, invoices.BillingCountry
FROM customers
INNER JOIN invoices
ON invoices.CustomerId = customers.CustomerId
WHERE customers.Country = 'Brazil'
"""
sql_query(invoices_bra)
# Out:
#     FirstName   LastName  InvoiceId          InvoiceDate BillingCountry
# 0        Luís  Gonçalves         98  2010-03-11 00:00:00         Brazil
# 1        Luís  Gonçalves        121  2010-06-13 00:00:00         Brazil
# 2        Luís  Gonçalves        143  2010-09-15 00:00:00         Brazil
# 3        Luís  Gonçalves        195  2011-05-06 00:00:00         Brazil
# 4        Luís  Gonçalves        316  2012-10-27 00:00:00         Brazil
# 5        Luís  Gonçalves        327  2012-12-07 00:00:00         Brazil
# 6        Luís  Gonçalves        382  2013-08-07 00:00:00         Brazil
# 7     Eduardo    Martins         25  2009-04-09 00:00:00         Brazil
# 8     Eduardo    Martins        154  2010-11-14 00:00:00         Brazil
# 9     Eduardo    Martins        177  2011-02-16 00:00:00         Brazil
# 10    Eduardo    Martins        199  2011-05-21 00:00:00         Brazil
# 11    Eduardo    Martins        251  2012-01-09 00:00:00         Brazil
# ...

# %% [markdown]
# 2. Facturas de Clientes de Brasil*

# %%
clientes_bra = """ 

SELECT invoices.InvoiceId
FROM customers
INNER JOIN invoices
ON invoices.CustomerId = customers.CustomerId
WHERE customers.Country = 'Brazil'
"""
sql_query(clientes_bra)
# Out:
#     InvoiceId
# 0          98
# 1         121
# 2         143
# 3         195
# 4         316
# 5         327
# 6         382
# 7          25
# 8         154
# 9         177
# 10        199
# 11        251
# 12        372
# 13        383
# 14         57
# 15         68
# 16        123
# 17        252
# 18        275
# 19        297
# 20        349
# 21         34
# 22        155
# 23        166
# 24        221
# 25        350
# 26        373
# 27        395
# 28         35
# 29         58
# 30         80
# 31        132
# 32        253
# 33        264
# 34        319

# %% [markdown]
# 3. Muestra cada factura asociada a cada agente de ventas con su nombre completo*

# %%
invoices_por_agentes =  """ 

SELECT invoices.InvoiceId, customers.SupportRepId AS Sales_representative, employees.FirstName, employees.LastName
FROM employees
INNER JOIN customers 
ON customers.SupportRepId = employees.EmployeeId

INNER JOIN invoices
ON invoices.CustomerId = customers.CustomerId

"""
sql_query(invoices_por_agentes)
# Out:
#      InvoiceId  Sales_representative FirstName LastName
# 0           98                     3      Jane  Peacock
# 1          121                     3      Jane  Peacock
# 2          143                     3      Jane  Peacock
# 3          195                     3      Jane  Peacock
# 4          316                     3      Jane  Peacock
# ..         ...                   ...       ...      ...
# 407         88                     5     Steve  Johnson
# 408        217                     5     Steve  Johnson
# 409        240                     5     Steve  Johnson
# 410        262                     5     Steve  Johnson
# 411        314                     5     Steve  Johnson
#
# [412 rows x 4 columns]

# %% [markdown]
# 4. Muestra el nombre del cliente, el pais, el nombre del agente y el total

# %%
clientes = """ 

SELECT  customers.FirstName AS Customer_Name, customers.LastName AS Customer_LastName, customers.Country, customers.SupportRepId AS Sales_representative, invoices.Total
FROM customers
INNER JOIN invoices 
ON invoices.CustomerId = customers.CustomerId

"""
sql_query(clientes)
# Out:
#     Customer_Name Customer_LastName Country  Sales_representative  Total
# 0            Luís         Gonçalves  Brazil                     3   3.98
# 1            Luís         Gonçalves  Brazil                     3   3.96
# 2            Luís         Gonçalves  Brazil                     3   5.94
# 3            Luís         Gonçalves  Brazil                     3   0.99
# 4            Luís         Gonçalves  Brazil                     3   1.98
# ..            ...               ...     ...                   ...    ...
# 407          Puja        Srivastava   India                     3   5.94
# 408          Puja        Srivastava   India                     3   1.99
# 409          Puja        Srivastava   India                     3   1.98
# 410          Puja        Srivastava   India                     3  13.86
# 411          Puja        Srivastava   India                     3   8.91
#
# [412 rows x 5 columns]

# %% [markdown]
# 5. Muestra cada articulo de la factura con el nombre de la cancion

# %%
invoice_track_name = """ 

SELECT invoice_items.InvoiceId AS Invoice_Id, invoice_items.InvoiceLineId AS Invoice_Item, tracks.Name AS Song
FROM invoice_items
INNER JOIN tracks
ON tracks.TrackId = invoice_items.TrackId

GROUP BY invoice_items.InvoiceId
"""
sql_query(invoice_track_name)
# Out:
#      Invoice_Id  Invoice_Item                                  Song
# 0             1             1                     Balls to the Wall
# 1             2             3                 Put The Finger On You
# 2             3             7                           Dog Eat Dog
# 3             4            13                     Right Through You
# 4             5            22                    Your Time Has Come
# ..          ...           ...                                   ...
# 407         408          2207                             Bass Trap
# 408         409          2211  Trash, Trampoline And The Party Girl
# 409         410          2217                                Desire
# 410         411          2226                         Higher Ground
# 411         412          2240                              Hot Girl
#
# [412 rows x 3 columns]

# %% [markdown]
# 6. Muestra todas las conciones con su nombre, formato, album y genero

# %%
songs = """ 

SELECT tracks.Name AS Song, tracks.MediaTypeId AS Song_Type, albums.Title AS Album, genres.Name AS Genre
FROM tracks

INNER JOIN albums 
ON albums.AlbumId = tracks.AlbumId

INNER JOIN genres
ON genres.GenreId = tracks.GenreId

"""

sql_query(songs)
# Out:
#                                                    Song  Song_Type  \
# 0               For Those About To Rock (We Salute You)          1
# 1                                     Balls to the Wall          2
# 2                                       Fast As a Shark          2
# 3                                     Restless and Wild          2
# 4                                  Princess of the Dawn          2
# ...                                                 ...        ...
# 3498  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...          2
# 3499  String Quartet No. 12 in C Minor, D. 703 "Quar...          2
# 3500               L'orfeo, Act 3, Sinfonia (Orchestra)          2
# 3501  Quintet for Horn, Violin, 2 Violas, and Cello ...          2
# 3502  Die Zauberflöte, K.620: "Der Hölle Rache Kocht...          2
#
#                                                   Album      Genre
# 0                 For Those About To Rock We Salute You       Rock
# ...

# %% [markdown]
# 7. Muestra cuantas canciones hay en cada playlist y el nombre de cada playlist

# %%
playlists = """ 

SELECT playlists.Name AS Playlist_Name, COUNT (playlist_track.TrackId) AS Total_Songs
FROM playlist_track
INNER JOIN playlists
ON playlists.PlaylistId = playlist_track.PlaylistId 

GROUP BY playlist_track.PlaylistId 

"""
sql_query(playlists)
# Out:
#                  Playlist_Name  Total_Songs
# 0                        Music         3290
# 1                     TV Shows          213
# 2                   90’s Music         1477
# 3                        Music         3290
# 4                 Music Videos            1
# 5                     TV Shows          213
# 6              Brazilian Music           39
# 7                    Classical           75
# 8    Classical 101 - Deep Cuts           25
# 9   Classical 101 - Next Steps           25
# 10  Classical 101 - The Basics           25
# 11                      Grunge           15
# 12         Heavy Metal Classic           26
# 13                 On-The-Go 1            1

# %% [markdown]
# 8. Muestra cuánto ha vendido cada empleado

# %%
ventas_por_empleado = """ 
SELECT  customers.SupportRepId AS EmployeeId, 
        SUM(invoices.Total) AS Total_Ventas
FROM customers
INNER JOIN invoices
ON invoices.CustomerId = customers.CustomerId
GROUP BY customers.SupportRepId
"""
sql_query(ventas_por_empleado)
# Out:
#    EmployeeId  Total_Ventas
# 0           3        833.04
# 1           4        775.40
# 2           5        720.16

# %% [markdown]
# 9. Quien ha sido el agente de ventas que más ha vendido en 2009?

# %%
max_ventas_09 = """ 

SELECT employees.EmployeeId, SUM(invoices.Total) AS Total_Sales
FROM employees
INNER JOIN customers 
ON customers.SupportRepId = employees.EmployeeId

INNER JOIN invoices
ON invoices.CustomerId = customers.CustomerId

WHERE InvoiceDate LIKE '2009%' 

GROUP BY employees.EmployeeId
ORDER BY Total_Sales DESC
LIMIT 1
"""
sql_query(max_ventas_09)
# Out:
#    EmployeeId  Total_Sales
# 0           5       164.34

# %% [markdown]
# 10. Quien es son los 3 grupos que más han vendido?

# %%
grupos_max_ventas = """ 

SELECT artists.Name, sum (invoices.Total) AS Total_Quantity
FROM invoice_items
INNER JOIN tracks
ON tracks.TrackId = invoice_items.TrackId

INNER JOIN albums
ON albums.AlbumId = tracks.AlbumId

INNER JOIN artists
ON artists.ArtistId = albums.ArtistId

INNER JOIN invoices
ON invoice_items.InvoiceId = invoices.InvoiceId

GROUP BY artists.Name
ORDER BY Total_Quantity DESC
LIMIT 3

"""
sql_query(grupos_max_ventas)
# Out:
#           Name  Total_Quantity
# 0  Iron Maiden         1233.54
# 1           U2          895.59
# 2         Lost          833.70
